# %%
# import block
import pandas as pd

# %%
with open("TCGA_Reports.csv", mode='r') as file:
    report_df = pd.read_csv(file)

report_df.head(20)
# Out:
#                                      patient_filename  \
# 0   TCGA-BP-5195.25c0b433-5557-4165-922e-2c1eac9c26f0
# 1   TCGA-D7-8573.b7306a47-697d-4ed3-bbe1-81d49674a8f8
# 2   TCGA-EI-7004.13591eed-30e5-47a3-91be-7a370663d2d4
# 3   TCGA-EB-A82B.23E186C6-739C-4EF1-8788-79AA89C6E87A
# 4   TCGA-A6-3808.e1505f65-72ef-438d-a5e1-93ed8bf6635d
# 5   TCGA-29-1761.63defa27-e729-4514-bdd2-d887c4100854
# 6   TCGA-24-1616.d8c764d9-0fe8-488e-8aa1-da73a8c10b01
# 7   TCGA-IN-A6RO.C0E5F045-3F12-45CF-A6A4-034D99F2A719
# 8   TCGA-44-8119.c40ea4c8-8cbe-4a44-96d4-ae524a916449
# 9   TCGA-KK-A6E8.3716A52E-E0B7-4FE0-AC2B-07F2F3A0D6AD
# 10  TCGA-CR-7390.3dfbab9d-ed2c-49dd-a7d5-b67fa8fb921b
# 11  TCGA-C4-A0F1.8410F811-09E4-40B9-B3CF-5A6F3DE628BD
# 12  TCGA-HU-8249.508931ee-5e93-4e0b-bb41-0e6f85df5570
# 13  TCGA-BR-6801.975674c1-7cb6-4e9e-b9e4-32ff2504e260
# 14  TCGA-SX-A7SL.C495D1B8-5AAE-425D-B11B-77C84F928280
# 15  TCGA-MH-A857.465C49A8-2050-434A-AC95-9144E46972DB
# ...
